# %% [markdown]
# <a href="https://colab.research.google.com/github/nicole-calderon/EasyOCR/blob/main/trial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !sudo apt install tesseract-ocr
# !pip install pytesseract
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# tesseract-ocr is already the newest version (4.00~git2288-10f4998a-2).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'sudo apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 12 not upgraded.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# import easyocr
import cv2
from matplotlib import pyplot as plt
import numpy as np
import re
import pytesseract
from pytesseract import Output

# %%
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).
# /gdrive

# %%
# img = cv2.imread('/gdrive/MyDrive/tamuhack22/training-strips/cartoon1.png')

# #convert to grayscale
# def convert_grayscale(img):
#   img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
#   return img

# #noise removal
# def blur(img, param):
#     img = cv2.medianBlur(img,param)
#     return img

# def threshold(img):
#   img = cv2.threshold(img,0,255,cv2.THRESH_BINARY + cv2.THRESH_OTSU)[1]
#   return img

# %%
from google.colab.patches import cv2_imshow

# %%
image = cv2.imread('/gdrive/MyDrive/tamuhack22/training-strips/cartoon2.PNG')
thresh = cv2.threshold(image, 150, 255, cv2.THRESH_BINARY_INV)[1]

result = cv2.GaussianBlur(thresh, (5,5), 0)
result = 255 - result

data = pytesseract.image_to_string(result, lang='eng',config='--psm 6')
print(data)

cv2_imshow(thresh)
cv2_imshow(result)
cv2.waitKey()
# Out:
# PEOPLE INTHE PARK KEEP
# FLYING DRONES NEAR ME,
# SOTVE BU ASSEN
# ® SHOOT HET DOWN.
# { coouven
# TPERES ONE NOU.
# We rR ATEN
# nL \
# f gs
# weed
# <PIL.Image.Image image mode=RGB size=190x281>
# <PIL.Image.Image image mode=RGB size=190x281>
# -1

# %%
img = cv2.imread('/gdrive/MyDrive/tamuhack22/training-strips/cartoon1.png')

d = pytesseract.image_to_data(img, output_type=Output.DICT)


conversation =''
n_boxes = len(d['level'])
for i in range(n_boxes):
    conversation += d['text'][i] + ' '
    (x, y, w, h) = (d['left'][i], d['top'][i], d['width'][i], d['height'][i])
    cv2.rectangle(img, (x, y), (x + w, y + h), (0, 255, 0), 2)

print("conversation:" + conversation)
cv2_imshow(img)
cv2.waitKey(0)
# Out:
# conversation:         ..IM GETTING A RIDE. WITH KATIE To ADAM'S   WEDDING. HOPING To SEE BRIAN ON THE WAY!  OH, THATS 0L!   ..L CANT KEEP LIVING THIS LIE, SOIM   JUST GONNA COME OUT AND ADMIT   IE HAVE NO IDEA WHO ANY OF THE   PEOPLE. YOU KEEP MENTIONING ARE.    Py
# <PIL.Image.Image image mode=RGB size=343x412>
# -1

# %%
img = cv2.imread('/gdrive/MyDrive/tamuhack22/training-strips/cartoon13.PNG')

d = pytesseract.image_to_data(img, output_type=Output.DICT)


conversation =''
n_boxes = len(d['level'])
for i in range(n_boxes):
    conversation += d['text'][i] + ' '
    (x, y, w, h) = (d['left'][i], d['top'][i], d['width'][i], d['height'][i])
    cv2.rectangle(img, (x, y), (x + w, y + h), (0, 255, 0), 2)

print("conversation:" + conversation)
cv2_imshow(img)
cv2.waitKey(0)
# Out:
# conversation:              DAMMIT, WHY ARE THERE SO MANY  DIFFERENT SUBCULTURES OBSESSED  UIT STARING AT THE SKY?  WHAT ELSE COULD WE DISGUISE.  OUR SURVEILLANCE DRONES AS?  EATER BaLLoons? |  NO THAT GETS THE UFO PEOPLE.  AND THE WEATHER, PEDPLE.  DON'T KNOW WHOS WORSE.
# <PIL.Image.Image image mode=RGB size=266x362>
# -1

# %%
# image = cv2.imread('/gdrive/MyDrive/tamuhack22/training-strips/cartoon2.png')
# thresh = cv2.threshold(image, 150, 255, cv2.THRESH_BINARY_INV)[1]

# result = cv2.GaussianBlur(thresh, (5,5), 0)
# result = 255 - result

# data = pytesseract.image_to_string(result, lang='eng',config='--psm 6')
# print(data)

# cv2_imshow(thresh)
# cv2_imshow(result)
# cv2.waitKey()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-30-dfaf41efff83> in <module>
#       2 thresh = cv2.threshold(image, 150, 255, cv2.THRESH_BINARY_INV)[1]
#       3
# ----> 4 result = cv2.GaussianBlur(thresh, (5,5), 0)
#       5 result = 255 - result
#       6
#
# error: OpenCV(4.6.0) /io/opencv/modules/imgproc/src/smooth.dispatch.cpp:617: error: (-215:Assertion failed) !_src.empty() in function 'GaussianBlur'

# %%
# !sudo apt-get install tesseract-ocr

# %%
# h,w,c = img.shape

# boxes = pytesseract.image_to_boxes(img)

# for b in boxes.splitlines():
#   b = b.split(' ')
#   img = cv2.rectangle(img, (int(b[1]), h - int(b[2])),(int(b[3]), h- int(b[4])), (0,255,0),2 )

# cv2_imshow(img)
# cv2.waitKey(0)
# cv2.destroyAllWindows()

# %%
# d = pytesseract.image_to_data(img, output_type=Output.DICT)
# print(d.keys())

# n_boxes = len(d['text'])

# print(n_boxes)

#for i in range(n_boxes):
  
  # if (int(float(d['conf'][i])) > 60):
  #   (x,y,w,h) = (d['left'][i], d['top'][i], d['width'][i], d['height'][i])
  #   img = cv2.rectangle(img, (x,y), (x+w, y+h), (0,255,0), 2)

# cv2_imshow(img)
# cv2.waitKey(0)
# cv2.destroyAllWindows()

# %%
# custom_config = r'--oem 3 --psm 6 '
# print(pytesseract.image_to_string(img,config=custom_config))
